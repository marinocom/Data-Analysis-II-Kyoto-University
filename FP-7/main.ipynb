# %% [markdown]
# # Final Project FP-5:  Descriptive Statistics
#
#
# <br>
# <br>

# %% [markdown]
# # Analysis of US Airline Flight Delays and Cancellations
#
#
# ### Overview:
#
# * **Name**:  Oliveros Marino
# * **Student number**:  B990378419
#
# <br>

# %% [markdown]
# ### Purpose:
#
# * The purpose of this project is to analyze the factors that contribute to airline flight delays and cancellations in the United States. This analysis will be conducted with data from US domestic flights in the year 2024.
#
# * The key **dependent variables** (DVs) is:
#     - ArrDelay (Arrival Delay in minutes)
#
# * Key **independent variables** (IVs) include:
#     - DepDelay (Departure delay in minutes)
#     - DayOfWeek
#     - CRSDepTime (Computer Reservation System Departure Time)
#     - Reporting_Airlines (Airline Carrier Code)
#     - Dest
#     - Distance
#     - Month
#
# * This dataset contains data from all major US domestic flights in 2024. The dataset includes 1 primary dependent variable (arrival in minutes) and 7 key independent variables. The full dataset contains 110 total variables. In the GitHub under dataReadme.md further description of all of this variables provided by BTS can be found. In total there are 7,079,061 entries in the dataset, this does not mean all flights in 2024 in the US, just the ones tracked by BTS. For the sake of this project only the flights departing from Philadelphia International Airport (PHL) will be analysed. This means the dataset goes from 7M to 100k flights/entries.
#
# <br>

# %% [markdown]
# ### Dataset source:
#
# The data comes from the **Bureau of Transportation Statistics (BTS)** - [Airline On-Time Performance Data](https://www.transtats.bts.gov/DL_SelectFields.aspx?gnoyr_VQ=FGJ&QO_fu146_anzr=b0-gvzr).
#
# This is maintained by the U.S. Department of Transportation and provides data on flights operated by large air carriers.
#
# We will use data from 2024 (January-December)
# <br>
# <br>
# ### Download instructions:
#
# This website contains the option to download individual months in a .csv format, without a need of registration. We obtained the data for January-December 2024, these 12 .csv files will be conjoined into one.
#
# Another feature of the website is the option to choose specifically which variables of data to download, for the sake of this project the downloaded data contains all possible variables.
# <br>
# <br>
# ### References
#
# Here are a some papers that have used the BTS Airline On-Time Performance dataset:
#
# *    Fleurquin, P., Ramasco, J. J., & Eguíluz, V. M. (2013)
#     Systemic delay propagation in the US airport network
#     Scientific Reports, 3, 1159.
#     DOI: [10.1038/srep01159](https://doi.org/10.1038/srep01159)
#
#
# *    Gui, G., Liu, F., Sun, J., Yang, J., Zhou, Z., & Zhao, D. (2020)
#     Flight delay prediction based on aviation big data and machine learning
#     IEEE Transactions on Vehicular Technology, 69(1), 140-150.
#     DOI: [10.1109/TVT.2019.2954094](https://doi.org/10.1109/TVT.2019.2954094)
#
#
# *    Kalliguddi, A. M., & Leboulluec, A. K. (2017)
#     Predictive modeling of aircraft flight delay
#     Universal Journal of Management, 5(10), 485-491.
#     DOI: [10.13189/ujm.2017.051003](https://doi.org/10.13189/ujm.2017.051003)
#
#
# *    Kim, Y. J., Choi, S., Briceno, S., & Mavris, D. (2016)
#     Prediction of weather-induced airline delays based on machine learning algorithms
#     <br>2016 IEEE/AIAA 35th Digital Avionics Systems Conference (DASC).
#     DOI: [10.1109/DASC.2016.7777956](https://doi.org/10.1109/DASC.2016.7777956)
#
#
# *    Manna, S., Biswas, S., Kundu, R., Rakshit, S., Gupta, P., & Barman, S. (2017)
#     A statistical approach to predict flight delay using gradient boosted decision tree
#     2017 International Conference on Computational Intelligence in Data Science (ICCIDS).
#     DOI: [10.1109/ICCIDS.2017.8272656](https://doi.org/10.1109/ICCIDS.2017.8272656)

# %% [markdown]
# ___
#
# ## Parse Data

# %%
# Import the parse_data module
import parse_data

# %%
# Parse the flight data
df = parse_data.parse_flight_data('data.csv')

# %% [markdown]
# ___
#
# ## Descriptive Statistics

# %%
# Import the descriptive module
import descriptive

# %%
descriptive.display_central_tendency_table(df, num=1)
descriptive.display_dispersion_table(df, num=2)
# Out:
# <br><br><p><span style="font-size: 1.2em;"><b>Table 1</b>: Central tendency summary statistics.</span></p>
#         arrival_delay  departure_delay  day_of_week  scheduled_dep_time  \
# mean         8.535498        15.113283     4.001053         1347.374909
# median      -8.000000        -2.000000     4.000000         1345.000000
# mode       -15.000000        -5.000000     1.000000          600.000000
#
#          distance     month
# mean    890.54806  6.694212
# median  678.00000  7.000000
# mode    666.00000  8.000000
# <br><br><p><span style="font-size: 1.2em;"><b>Table 2</b>: Dispersion summary statistics.</span></p>
#          arrival_delay  departure_delay  day_of_week  scheduled_dep_time  \
# st.dev.          65.51            63.18         2.02               482.0
# min             -72.00           -36.00         1.00               107.0
# max            2189.00          2204.00         7.00              2359.0
# range          2261.00          2240.00         6.00              2252.0
# 25th            -18.00            -6.00         2.00               909.0
# 75th             11.00            10.00         6.00              1832.0
# IQR              29.00            16.00         4.00               923.0
#
#          distance  month
# st.dev.     597.6   3.27
# min          36.0   1.00
# max        2521.0  12.00
# range      2485.0  11.00
# 25th        453.0   4.00
# 75th       1013.0   9.00
# IQR         560.0   5.00

# %%
descriptive.plot_descriptive(df)
# Out:
# <p><span style="font-size: 1.2em;"><b>Figure 1</b>: Correlations amongst main variables.</span></p><br><br>

# %% [markdown]
# ___

# %% [markdown]
# ## Classical Hypothesis Analyses

# %%
# Import the classical hypothesis analyses model
import classical

# %%
# Run the analyses
classical.run_all_analyses(df, [1,4])
# Out:
# <p><span style="font-size: 1.2em;"><b>Analysis 1</b>: Cascading Delay Effect by Flight Distance</span></p>
# **Fisher Z-test for Correlation Difference**
# - Test Statistic: 33.0312
# - p-value: 0.0000
# - Interpretation: Short flights show significantly stronger correlation (r=0.977) compared to long flights (r=0.959). This suggests pilots on longer flights can make up time during cruise.
# <p><span style="font-size: 1.2em;"><b>Analysis 4</b>: Seasonal Effects on Delay Recovery</span></p>
# **Welch's t-test for Seasonal Recovery Difference**
# - Test Statistic: 4.5100
# - p-value: 0.0000
# - Interpretation: Winter recovery rate: 0.760, Summer: 0.576. Winter flights show significantly better delay recovery, which is unexpected and warrants further investigation.

# %% [markdown]
# ____

# %% [markdown]
# ## Machine Learning Analyses - Improved

# %%
import improved

# %%
improved.run_improved_analyses(df)
# Out:
# ### Improved Analysis 2: Improved Feature Engineering & Importance
# **Comparison with Original**
#
#
# - **Improved RMSE**: 13.75 min
# - **Improved R²**: 0.9519
# - **Strategy**: Used **Log Transformation** on target and **Cyclical Encoding** for time.
# - **Dimensionality Reduction**: Reduced destination sparsity using **PCA**.
# ### Improved Analysis 4: Model Comparison with Dimensionality Reduction
# **Dimensionality Reduction Impact**
#
#
# - **Finding**: Preprocessing the data into a dense PCA space improves convergence for models like GBM.
# - **Ridge Performance**: The **Ridge (Robust)** model benefits from **RobustScaler**, which reduces the impact of extreme flight delay outliers.
# - **Ensemble Advantage**: **GBM (Log-Target)** typically performs best as it captures non-linear patterns in the log-transformed delay space.
# - **Dimensionality Reduction**: By using **PCA** on destinations, we avoid the sparse matrix issues found in the original analysis.
